# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cpu.html
# !pip install torch-geometric
# !pip install pandas scikit-learn matplotlib
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Requirement already satisfied: torch in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (2.9.1+cpu)
# Requirement already satisfied: torchvision in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (0.24.1+cpu)
# Requirement already satisfied: torchaudio in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (2.9.1+cpu)
# Requirement already satisfied: filelock in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torchvision) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch) (3.0.2)
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cpu.html
# ERROR: Could not find a version that satisfies the requirement pyg_lib (from versions: none)
# ERROR: No matching distribution found for pyg_lib
# Requirement already satisfied: torch-geometric in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (2.7.0)
# Requirement already satisfied: aiohttp in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (3.13.2)
# Requirement already satisfied: fsspec in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (2025.9.0)
# Requirement already satisfied: jinja2 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (2.2.4)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (7.1.3)
# Requirement already satisfied: pyparsing in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (3.2.5)
# Requirement already satisfied: requests in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from torch-geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from aiohttp->torch-geometric) (1.22.0)
# Requirement already satisfied: idna>=2.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp->torch-geometric) (3.10)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch-geometric) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from requests->torch-geometric) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from requests->torch-geometric) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from tqdm->torch-geometric) (0.4.6)
# Requirement already satisfied: pandas in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\gsr20\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import torch
import torch_geometric

print(torch.__version__)
print(torch_geometric.__version__)
# Out:
# 2.9.1+cpu
# 2.7.0

# %%
import pandas as pd
import numpy as np
import torch
from torch import nn
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
features_df = pd.read_csv("data/elliptic_txs_features.csv", header=None)
labels_df = pd.read_csv("data/elliptic_txs_classes.csv")
edges_df = pd.read_csv("data/elliptic_txs_edgelist.csv")

# %%
features_df = features_df.rename(columns={0: "txId", 1: "time_step"})
tx_ids = features_df["txId"].values
feature_cols = features_df.columns[2:]
X = features_df[feature_cols].values

labels_df = labels_df.rename(columns={"txId": "txId", "class": "label"})
labels_df = labels_df[labels_df["label"] != "unknown"]
labels_df["y"] = (labels_df["label"] == "1").astype(int)

labeled = features_df.merge(labels_df[["txId", "y"]], on="txId", how="left")
mask_labeled = labeled["y"].notna()
y_full = labeled["y"].fillna(-1).astype(int).values
time_steps = labeled["time_step"].values

# %%
tx_id_to_idx = {tx_id: i for i, tx_id in enumerate(tx_ids)}
edges_df = edges_df[edges_df["txId1"].isin(tx_id_to_idx) & edges_df["txId2"].isin(tx_id_to_idx)]
src = edges_df["txId1"].map(tx_id_to_idx).values
dst = edges_df["txId2"].map(tx_id_to_idx).values
edge_index = np.vstack((src, dst))
edge_index = np.concatenate((edge_index, np.vstack((dst, src))), axis=1)
edge_index = torch.tensor(edge_index, dtype=torch.long)

x = torch.tensor(X, dtype=torch.float)
y = torch.tensor(y_full, dtype=torch.long)

# %%
labeled_indices = np.where(y_full != -1)[0]
y_labeled = y_full[labeled_indices]

train_idx, test_idx = train_test_split(labeled_indices, test_size=0.2, stratify=y_labeled, random_state=42)
train_idx, val_idx = train_test_split(train_idx, test_size=0.2, stratify=y_full[train_idx], random_state=42)

train_mask = torch.zeros(x.size(0), dtype=torch.bool)
val_mask = torch.zeros(x.size(0), dtype=torch.bool)
test_mask = torch.zeros(x.size(0), dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx] = True
test_mask[test_idx] = True

# %%
data = Data(x=x, edge_index=edge_index, y=y)
data.train_mask = train_mask
data.val_mask = val_mask
data.test_mask = test_mask

# %%
X_train = X[train_idx]
X_val = X[val_idx]
X_test = X[test_idx]

y_train = y_full[train_idx]
y_val = y_full[val_idx]
y_test = y_full[test_idx]

log_reg = LogisticRegression(max_iter=1000, n_jobs=-1)
log_reg.fit(X_train, y_train)

y_val_prob = log_reg.predict_proba(X_val)[:, 1]
y_val_pred = (y_val_prob >= 0.5).astype(int)

y_test_prob = log_reg.predict_proba(X_test)[:, 1]
y_test_pred = (y_test_prob >= 0.5).astype(int)

val_acc = accuracy_score(y_val, y_val_pred)
val_f1 = f1_score(y_val, y_val_pred)
val_auc = roc_auc_score(y_val, y_val_prob)

test_acc = accuracy_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_prob)

print("Baseline Logistic Regression")
print("Val:  Acc:", val_acc, "F1:", val_f1, "AUC:", val_auc)
print("Test: Acc:", test_acc, "F1:", test_f1, "AUC:", test_auc)
# Out:
# Baseline Logistic Regression
# Val:  Acc: 0.9647027244665146 F1: 0.8084486525855791 AUC: 0.9655740548749804
# Test: Acc: 0.9619886180607753 F1: 0.7941860465116279 AUC: 0.967897182388396

# %%
class GCN(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, dropout=0.5):
        super().__init__()
        self.conv1 = GCNConv(in_channels, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, out_channels)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = nn.functional.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data = data.to(device)

train_labels = data.y[data.train_mask]
class_counts = torch.bincount(train_labels)
class_weights = (train_labels.size(0) / (2.0 * class_counts)).to(torch.float32).to(device)

model = GCN(in_channels=data.x.size(1), hidden_channels=64, out_channels=2, dropout=0.5).to(device)
criterion = nn.CrossEntropyLoss(weight=class_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=5e-4)

# %%
def evaluate(split="val"):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        if split == "val":
            mask = data.val_mask
        elif split == "test":
            mask = data.test_mask
        else:
            mask = data.train_mask
        logits = out[mask]
        preds = logits.argmax(dim=1).cpu().numpy()
        probs = torch.softmax(logits, dim=1)[:, 1].cpu().numpy()
        labels = data.y[mask].cpu().numpy()
        acc = accuracy_score(labels, preds)
        f1 = f1_score(labels, preds)
        auc = roc_auc_score(labels, probs)
    return acc, f1, auc

# %%
epochs = 100
val_history = []
for epoch in range(1, epochs + 1):
    model.train()
    optimizer.zero_grad()
    out = model(data.x, data.edge_index)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])
    loss.backward()
    optimizer.step()
    if epoch % 5 == 0 or epoch == 1:
        val_acc, val_f1, val_auc = evaluate("val")
        val_history.append((epoch, val_acc, val_f1, val_auc))
        print(f"Epoch {epoch:03d} | Loss {loss.item():.4f} | Val Acc {val_acc:.4f} | Val F1 {val_f1:.4f} | Val AUC {val_auc:.4f}")
# Out:
# Epoch 001 | Loss 0.9966 | Val Acc 0.3343 | Val F1 0.1700 | Val AUC 0.4014
# Epoch 005 | Loss 0.7316 | Val Acc 0.5187 | Val F1 0.2517 | Val AUC 0.6863
# Epoch 010 | Loss 0.5516 | Val Acc 0.7055 | Val F1 0.3603 | Val AUC 0.8484
# Epoch 015 | Loss 0.4824 | Val Acc 0.7639 | Val F1 0.4170 | Val AUC 0.8882
# Epoch 020 | Loss 0.4374 | Val Acc 0.7896 | Val F1 0.4491 | Val AUC 0.9070
# Epoch 025 | Loss 0.4055 | Val Acc 0.8039 | Val F1 0.4666 | Val AUC 0.9169
# Epoch 030 | Loss 0.3863 | Val Acc 0.8092 | Val F1 0.4749 | Val AUC 0.9233
# Epoch 035 | Loss 0.3728 | Val Acc 0.8151 | Val F1 0.4839 | Val AUC 0.9281
# Epoch 040 | Loss 0.3627 | Val Acc 0.8231 | Val F1 0.4954 | Val AUC 0.9320
# Epoch 045 | Loss 0.3465 | Val Acc 0.8351 | Val F1 0.5121 | Val AUC 0.9350
# Epoch 050 | Loss 0.3417 | Val Acc 0.8435 | Val F1 0.5241 | Val AUC 0.9374
# Epoch 055 | Loss 0.3317 | Val Acc 0.8478 | Val F1 0.5314 | Val AUC 0.9395
# Epoch 060 | Loss 0.3248 | Val Acc 0.8517 | Val F1 0.5379 | Val AUC 0.9414
# Epoch 065 | Loss 0.3217 | Val Acc 0.8548 | Val F1 0.5431 | Val AUC 0.9430
# Epoch 070 | Loss 0.3116 | Val Acc 0.8595 | Val F1 0.5505 | Val AUC 0.9445
# Epoch 075 | Loss 0.3114 | Val Acc 0.8643 | Val F1 0.5595 | Val AUC 0.9459
# Epoch 080 | Loss 0.3094 | Val Acc 0.8686 | Val F1 0.5682 | Val AUC 0.9474
# Epoch 085 | Loss 0.3027 | Val Acc 0.8720 | Val F1 0.5752 | Val AUC 0.9487
# Epoch 090 | Loss 0.3008 | Val Acc 0.8749 | Val F1 0.5821 | Val AUC 0.9500
# Epoch 095 | Loss 0.2978 | Val Acc 0.8784 | Val F1 0.5893 | Val AUC 0.9511
# Epoch 100 | Loss 0.2891 | Val Acc 0.8820 | Val F1 0.5966 | Val AUC 0.9521

# %%
test_acc, test_f1, test_auc = evaluate("test")
print("GCN Test Performance")
print("Acc:", test_acc, "F1:", test_f1, "AUC:", test_auc)
# Out:
# GCN Test Performance
# Acc: 0.9458821002899174 F1: 0.6514522821576764 AUC: 0.9447645026282734

# %%
epochs_list = [e for e, a, f, u in val_history]
auc_list = [u for e, a, f, u in val_history]

plt.figure()
plt.plot(epochs_list, auc_list, marker="o")
plt.xlabel("Epoch")
plt.ylabel("Validation AUC")
plt.title("GCN Validation AUC over Epochs")
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report

model.eval()
with torch.no_grad():
    out = model(data.x, data.edge_index)
    logits_test = out[data.test_mask]
    y_test_true = data.y[data.test_mask].cpu().numpy()
    y_test_pred = logits_test.argmax(dim=1).cpu().numpy()

cm = confusion_matrix(y_test_true, y_test_pred)
print("Confusion Matrix:")
print(cm)

print("\nClassification Report:")
print(classification_report(y_test_true, y_test_pred, digits=4))
# Out:
# Confusion Matrix:
# [[8338   66]
#  [ 438  471]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.9501    0.9921    0.9707      8404
#            1     0.8771    0.5182    0.6515       909
#
#     accuracy                         0.9459      9313
#    macro avg     0.9136    0.7551    0.8111      9313
# weighted avg     0.9430    0.9459    0.9395      9313

# %%
edge_index_cpu = data.edge_index.cpu()
fraud_mask = (data.y == 1).cpu()
neighbor_ratios = []

for i in test_idx:
    neighbors = edge_index_cpu[1][edge_index_cpu[0] == i]
    if neighbors.numel() > 0:
        ratio = fraud_mask[neighbors].float().mean().item()
        neighbor_ratios.append(ratio)

if len(neighbor_ratios) > 0:
    avg_ratio = float(np.mean(neighbor_ratios))
    print("Average fraudulent neighbor ratio for test nodes:", avg_ratio)
# Out:
# Average fraudulent neighbor ratio for test nodes: 0.03228519355597627
